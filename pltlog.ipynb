# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np

log_file = "./logs/BeamRiderNoFrameskip-v4/2018-08-18-10-55-56-344351/monitor.csv"
data = pandas.read_csv(log_file, index_col=None, comment='#')
data = data['r']
plt.plot(data)
plt.show()
